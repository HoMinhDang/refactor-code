# %%
import os
import sys
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# %%
# from models.MiT import MiT
# from models.ResNet import ResNetEncoder
# from models.proposed import CrackAwareFusionNet
# from thop import profile
# import torch

# %%
# model = CrackAwareFusionNet(crackam=False, crackspam=False, attn_gate=False)
# x = torch.randn(1, 3, 256, 256)
# feats = model(x)
# for f in feats:
#     print(f.shape)
# flops, params = profile(model, inputs=(x, ))
# print(f"GMACs: {flops / 1e9:.2f}")
# print(f"Params (M): {params / 1e6:.2f} ")

# %%
from models.CrackModule import MODEL_REGISTRY, create_model, CrackModule

print(MODEL_REGISTRY)
# Out:
# {'cafnet': <class 'models.proposed.CrackAwareFusionNet'>}

# %%
from omegaconf import OmegaConf
cfg = OmegaConf.load("D:\\Code\\Python\\KLTN\\config\\train.yaml")
model_cfg = OmegaConf.load("D:\\Code\\Python\\KLTN\\config\\model.yaml")

# %%
selected_model = cfg.model.selected
model_info = model_cfg[selected_model]

print(model_info.name)
print(model_info.hparams)
# Out:
# cafnet
# {'in_channels': 3, 'embed_dims': [64, 64, 128, 256], 'num_heads': [1, 2, 4, 8], 'mlp_ratios': [4, 4, 4, 4], 'reduction_ratios': [8, 4, 2, 1], 'depths': [2, 2, 2, 2], 'crackam': True, 'crackspam': True, 'attn_gate': True}

# %%
model = CrackModule(model_info.name, model_info.hparams)

# %%
print(model)
# Out:
# CrackModule(
#   (model): CrackAwareFusionNet(
#     (mit): MiT(
#       (stages): ModuleList(
#         (0): ModuleList(
#           (0): OverLapPatchEmbedding(
#             (proj): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#             (norm): LayerNorm2d((64,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): Sequential(
#             (0): MiTBlock(
#               (attn): EfficientMSA(
#                 (norm): LayerNorm2d((64,), eps=1e-05, elementwise_affine=True)
#                 (sr): Conv2d(64, 64, kernel_size=(8, 8), stride=(8, 8))
#                 (sr_norm): LayerNorm2d((64,), eps=1e-05, elementwise_affine=True)
#                 (attn): MultiheadAttention(
#                   (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#                 )
#                 (proj): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (ffn): MixFFN(
# ...
